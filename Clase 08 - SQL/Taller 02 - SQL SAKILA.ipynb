# %% [markdown]
# # Taller 2 – SQL Práctico (Sakila)
#
# Usando la base de datos de muestra 'SAKILA' en MySQL, resolver los siguientes ejercicios
#
# **El entregable debe ser un archivo llamado TALLER02_NombreApellido.sql, deben subirlo con comentarios al repositorio de github**

# %% [markdown]
# ## Conexión
# ```sql
# USE sakila;
# ```

# %% [markdown]
# ## Parte 1 – SELECT y WHERE
#
# 1. Mostrar nombre y apellido de todos los clientes
# 2. Películas con duración mayor a 120 minutos

# %% [markdown]
# ## Parte 2 – ORDER BY
# 3. Ordenar clientes por apellido
# 4. Top 5 películas más largas

# %% [markdown]
# ## Parte 3 – INNER JOIN
# 5. Pagos con nombre del cliente (JOIN entre Payment - Customer)
# 6. Películas alquiladas (JOIN entre Rental - Inventory - Film)

# %% [markdown]
# ## Parte 4 – LEFT JOIN
# 7. Todos los clientes y sus pagos (LEFT JOIN entre Payment - Customer)
# 8. Clientes sin pagos (LEFT JOIN entre Payment - Customer pero usando WHERE)

# %% [markdown]
# ## Parte 5 – INSERT, UPDATE, DELETE
# **RECUERDA USAR WHERE**
#
# 9. Insertar actor temporal
# 10. Actualizar actor
# 11. Eliminar actor

# %% [markdown]
# ## Parte 6 - Consultas Avanzadas
# 12. Top 5 clientes con más pagos
# 13. Películas más alquiladas
