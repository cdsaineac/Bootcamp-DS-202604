# %% [markdown]
# # Introducción a Pandas: Principales Funciones y Usos
#
# En este Notebook, exploraremos **pandas**, una de las librerías más populares de Python para la manipulación y análisis de datos. Aprenderemos sus principales funciones y cómo usarlas en proyectos reales.
#
# ---
#
# ## 1. ¿Qué es Pandas?
#
# **Pandas** es una librería de Python diseñada para trabajar con datos tabulares, como hojas de cálculo o bases de datos. Es especialmente útil para:
# - Leer y escribir datos en diferentes formatos (CSV, Excel, JSON, etc.).
# - Limpiar y transformar datos.
# - Realizar análisis estadísticos.
# - Visualizar datos (en combinación con otras librerías como Matplotlib o Seaborn).
#
# ### Instalación de Pandas
# Si no tienes pandas instalado, puedes instalarlo con:
# ```bash
# pip install pandas

# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# ...

# %% [markdown]
# # 2. Principales Estructuras de Datos en Pandas
# Pandas tiene dos estructuras principales:
#
# **1. Series:** es una estructura unidimensional, similar a una lista o columna en una tabla.
#
# **2. DataFrame:** es una estructura bidimensional, similar a una tabla con filas y columnas.

# %% [markdown]
# # 3. Principales Funciones y Usos de Pandas

# %% [markdown]
# ### 3.1. Crear un DataFrame
#
# Un DataFrame es la estructura principal de pandas. Podemos crearlo a partir de un diccionario, una lista o leyendo un archivo.

# %%
import pandas as pd

datos = pd.DataFrame(
    data={
        "Nombre": ["Juan", "María", "Pedro", "Ana"],
        "Edad": [28, 34, 22, 30],
        "Ciudad": ["Madrid", "Barcelona", "Valencia", "Sevilla"],
    }
)
datos
# Out:
#   Nombre  Edad     Ciudad
# 0   Juan    28     Madrid
# 1  María    34  Barcelona
# 2  Pedro    22   Valencia
# 3    Ana    30    Sevilla

# %%
datos_excel = pd.read_excel("archivo_excel.xlsx")
datos_excel
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 0         1000567495   INBOUND                         F & M
# 1         1000567490   INBOUND                       Luminar
# 2         1000567484   INBOUND                      Flexilux
# 3         1000567483   INBOUND                       Brewers
# 4         1000567481   INBOUND                        McGrey
# ..               ...       ...                           ...
# 163       1000567351   INBOUND                  Total Source
# 164       1000567364   INBOUND                       Mueller
# 165       1000567374   INBOUND                            EM
# 166       1000567376   INBOUND                        Ripley
# 167       1000567378   INBOUND                    Interalloy
#
#     buyer.organizationIdentifier  \
# 0                      LightTree
# 1                      LightTree
# 2                      LightTree
# 3                      LightTree
# 4                      LightTree
# ...

# %% [markdown]
# ### 3.2. Leer un Archivo CSV
# Pandas puede leer archivos CSV directamente desde una URL o un archivo local.

# %%
datos_csv = pd.read_csv("Order_v3.csv", encoding="latin-1")
datos_csv
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 0          100044349  OUTBOUND                     LightTree
# 1          100044350  OUTBOUND                     LightTree
# 2          100044353  OUTBOUND                     LightTree
# 3          100055001  OUTBOUND                     LightTree
# 4          100055003  OUTBOUND                     LightTree
# ..               ...       ...                           ...
# 209        100044330  OUTBOUND                     LightTree
# 210        100044331  OUTBOUND                     LightTree
# 211        100044332  OUTBOUND                     LightTree
# 212        100055004  OUTBOUND                     LightTree
# 213        100055011  OUTBOUND                     LightTree
#
#     buyer.organizationIdentifier  \
# 0                           AHTD
# 1                           AHTD
# 2                           AHTD
# 3                           AHTD
# 4                           AHTD
# ...

# %% [markdown]
# **Lectura de otro tipo de archivos:**
#
# - ```pd.read_excel(url)```
# - ```pd.read_json(url)```
# - ```pd.read_xml("archivo.xml")```

# %% [markdown]
# **Cargue local de archivos**

# %% [markdown]
# **Cargue de un archivo local:**

# %% [markdown]
# ### 3.3. Explorar Datos
# Pandas proporciona funciones útiles para explorar datos:
#
# ```head():``` Muestra las primeras filas.
#
# ```tail():``` Muestra las últimas filas.
#
# ```info():``` Proporciona información sobre el DataFrame.
#
# ```describe():``` Muestra estadísticas descriptivas.
#
# ```shape:``` Forma del DataFrame (Filas,Columnas)

# %%
datos_excel.head()
# Out:
#    orderIdentifier orderType vendor.organizationIdentifier  \
# 0       1000567495   INBOUND                         F & M
# 1       1000567490   INBOUND                       Luminar
# 2       1000567484   INBOUND                      Flexilux
# 3       1000567483   INBOUND                       Brewers
# 4       1000567481   INBOUND                        McGrey
#
#   buyer.organizationIdentifier shipFromInstructionLocation.locationIdentifier  \
# 0                    LightTree                               F & M - Columbus
# 1                    LightTree                   Luminar - Palm Beach Gardens
# 2                    LightTree                           Flexilux - Worcester
# 3                    LightTree                              Brewers - Phoenix
# 4                    LightTree                           McGrey - Mt Sterling
#
#   shipToLocation.locationIdentifier  orderStatus          createdDate  \
# ...

# %%
datos_excel.tail()
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 163       1000567351   INBOUND                  Total Source
# 164       1000567364   INBOUND                       Mueller
# 165       1000567374   INBOUND                            EM
# 166       1000567376   INBOUND                        Ripley
# 167       1000567378   INBOUND                    Interalloy
#
#     buyer.organizationIdentifier  \
# 163                    LightTree
# 164                    LightTree
# 165                    LightTree
# 166                    LightTree
# 167                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# 163                        Total Source - Waukesha
# 164                           Mueller - Pittsburgh
# 165                                  EM - Hemphill
# 166                               Ripley - Trenton
# 167                           Interalloy - Bozeman
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# ...

# %%
datos_excel.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 22 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   orderIdentifier                                 168 non-null    int64
#  1   orderType                                       168 non-null    str
#  2   vendor.organizationIdentifier                   168 non-null    str
#  3   buyer.organizationIdentifier                    168 non-null    str
#  4   shipFromInstructionLocation.locationIdentifier  168 non-null    str
#  5   shipToLocation.locationIdentifier               168 non-null    str
#  6   orderStatus                                     0 non-null      float64
#  7   createdDate                                     168 non-null    str
#  8   requestedShipDate                               168 non-null    str
# ...

# %%
datos_excel.describe()
# Out:
#        orderIdentifier  orderStatus     quantity    totalValue   lineCount  \
# count     1.680000e+02          0.0   168.000000  1.680000e+02  168.000000
# mean      1.000532e+09          NaN   283.410714  1.061578e+05    1.214286
# std       1.295037e+05          NaN   345.379984  2.384429e+05    0.774928
# min       1.000066e+09          NaN    44.000000  1.320000e+02    1.000000
# 25%       1.000567e+09          NaN    75.000000  5.356000e+03    1.000000
# 50%       1.000567e+09          NaN   124.000000  2.720500e+04    1.000000
# 75%       1.000567e+09          NaN   320.000000  1.104250e+05    1.000000
# max       1.000568e+09          NaN  1400.000000  1.769600e+06    4.000000
#
#        totalShippedQuantity  exclude  precio_unitario  precio_unitario_iva
# count                   0.0      0.0       168.000000           168.000000
# mean                    NaN      NaN       482.946429           574.706250
# ...

# %%
datos_excel.shape
# Out:
# (168, 22)

# %% [markdown]
# ### 3.4. Filtrar Datos

# %% [markdown]
# **Filtrar por columnas**

# %%
## Filtro una sola columna de información - Esto genera una serie de pandas
datos_excel['buyer.organizationIdentifier']
# Out:
# 0      LightTree
# 1      LightTree
# 2      LightTree
# 3      LightTree
# 4      LightTree
#          ...
# 163    LightTree
# 164    LightTree
# 165    LightTree
# 166    LightTree
# 167    LightTree
# Name: buyer.organizationIdentifier, Length: 168, dtype: str

# %%
## Filtro 2 o mas columnas de informacion - Esto genera un DataFrame de pandas
datos_excel[['vendor.organizationIdentifier','orderType', 'quantity']]
# Out:
#     vendor.organizationIdentifier orderType  quantity
# 0                           F & M   INBOUND       124
# 1                         Luminar   INBOUND       124
# 2                        Flexilux   INBOUND       124
# 3                         Brewers   INBOUND       124
# 4                          McGrey   INBOUND       320
# ..                            ...       ...       ...
# 163                  Total Source   INBOUND       124
# 164                       Mueller   INBOUND       320
# 165                            EM   INBOUND       320
# 166                        Ripley   INBOUND       320
# 167                    Interalloy   INBOUND       124
#
# [168 rows x 3 columns]

# %% [markdown]
# **Filtrado básico:**

# %%
datos_excel[(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics')]
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 19        1000567425   INBOUND                  SilverOptics
# 42        1000567251   INBOUND                  SilverOptics
# 61        1000567332   INBOUND                  SilverOptics
# 64        1000567338   INBOUND                  SilverOptics
# 75        1000567370   INBOUND                  SilverOptics
# 102       1000567463   INBOUND                  SilverOptics
# 135       1000567230   INBOUND                  SilverOptics
# 157       1000567315   INBOUND                  SilverOptics
#
#     buyer.organizationIdentifier  \
# 19                     LightTree
# 42                     LightTree
# 61                     LightTree
# 64                     LightTree
# 75                     LightTree
# 102                    LightTree
# 135                    LightTree
# 157                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# ...

# %% [markdown]
# **Filtrado multiplies condiciones:**

# %%
## Conjuncion con el simbolo &
datos_excel[(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics') & (datos_excel['quantity'] > 200)]
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 19        1000567425   INBOUND                  SilverOptics
# 64        1000567338   INBOUND                  SilverOptics
# 157       1000567315   INBOUND                  SilverOptics
#
#     buyer.organizationIdentifier  \
# 19                     LightTree
# 64                     LightTree
# 157                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# 19                            SilverOptics - Dover
# 64                            SilverOptics - Dover
# 157                           SilverOptics - Dover
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 19                               LT-2          NaN  2021-06-16T00:00:00
# 64                               LT-1          NaN  2021-06-16T00:00:00
# 157                              LT-2          NaN  2021-06-16T00:00:00
#
#        requestedShipDate requestedDeliveryDate  ... quantity quantityUnits  \
# ...

# %%
## Disyuncion con el simbolo |
datos_excel[(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics') | (datos_excel['quantity'] > 200)]
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 4         1000567481   INBOUND                        McGrey
# 5         1000567478   INBOUND                  Total Source
# 6         1000567477   INBOUND                         Hardy
# 7         1000567476   INBOUND                            EM
# 9         1000567468   INBOUND                       Mueller
# ..               ...       ...                           ...
# 160       1000567327   INBOUND                       Mueller
# 162       1000567346   INBOUND                    Interalloy
# 164       1000567364   INBOUND                       Mueller
# 165       1000567374   INBOUND                            EM
# 166       1000567376   INBOUND                        Ripley
#
#     buyer.organizationIdentifier  \
# 4                      LightTree
# 5                      LightTree
# 6                      LightTree
# 7                      LightTree
# 9                      LightTree
# ...

# %%
## Es posible combinar filtros de filas y de columnas para obtener solo la información que nos interesa
datos_excel[['vendor.organizationIdentifier','orderType', 'quantity']][(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics')]
# Out:
#     vendor.organizationIdentifier orderType  quantity
# 19                   SilverOptics   INBOUND       320
# 42                   SilverOptics   INBOUND        44
# 61                   SilverOptics   INBOUND       124
# 64                   SilverOptics   INBOUND       512
# 75                   SilverOptics   INBOUND        56
# 102                  SilverOptics   INBOUND        75
# 135                  SilverOptics   INBOUND       124
# 157                  SilverOptics   INBOUND       320

# %% [markdown]
# **Filtrado con función where:**

# %%
datos_excel.where(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics').dropna(subset=['vendor.organizationIdentifier'])
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 19      1.000567e+09   INBOUND                  SilverOptics
# 42      1.000567e+09   INBOUND                  SilverOptics
# 61      1.000567e+09   INBOUND                  SilverOptics
# 64      1.000567e+09   INBOUND                  SilverOptics
# 75      1.000567e+09   INBOUND                  SilverOptics
# 102     1.000567e+09   INBOUND                  SilverOptics
# 135     1.000567e+09   INBOUND                  SilverOptics
# 157     1.000567e+09   INBOUND                  SilverOptics
#
#     buyer.organizationIdentifier  \
# 19                     LightTree
# 42                     LightTree
# 61                     LightTree
# 64                     LightTree
# 75                     LightTree
# 102                    LightTree
# 135                    LightTree
# 157                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# ...

# %% [markdown]
# **Filtrado loc e iloc:**
#
# - ```loc:``` Se utiliza para seleccionar filas y columnas por etiquetas (nombres de filas y columnas).
#
# - ```iloc:``` Se utiliza para seleccionar filas y columnas por índices numéricos (posición).

# %% [markdown]
# ___loc___
#
# Me sirve para acceder por medio de filtros sobre las filas o por el indice especifico

# %%
datos_excel.loc[datos_excel['vendor.organizationIdentifier'] == 'SilverOptics']
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 19        1000567425   INBOUND                  SilverOptics
# 42        1000567251   INBOUND                  SilverOptics
# 61        1000567332   INBOUND                  SilverOptics
# 64        1000567338   INBOUND                  SilverOptics
# 75        1000567370   INBOUND                  SilverOptics
# 102       1000567463   INBOUND                  SilverOptics
# 135       1000567230   INBOUND                  SilverOptics
# 157       1000567315   INBOUND                  SilverOptics
#
#     buyer.organizationIdentifier  \
# 19                     LightTree
# 42                     LightTree
# 61                     LightTree
# 64                     LightTree
# 75                     LightTree
# 102                    LightTree
# 135                    LightTree
# 157                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# ...

# %%
datos_excel.loc[(datos_excel['vendor.organizationIdentifier'] == 'SilverOptics') & (datos_excel['quantity'] > 200)]
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier  \
# 19        1000567425   INBOUND                  SilverOptics
# 64        1000567338   INBOUND                  SilverOptics
# 157       1000567315   INBOUND                  SilverOptics
#
#     buyer.organizationIdentifier  \
# 19                     LightTree
# 64                     LightTree
# 157                    LightTree
#
#     shipFromInstructionLocation.locationIdentifier  \
# 19                            SilverOptics - Dover
# 64                            SilverOptics - Dover
# 157                           SilverOptics - Dover
#
#     shipToLocation.locationIdentifier  orderStatus          createdDate  \
# 19                               LT-2          NaN  2021-06-16T00:00:00
# 64                               LT-1          NaN  2021-06-16T00:00:00
# 157                              LT-2          NaN  2021-06-16T00:00:00
#
#        requestedShipDate requestedDeliveryDate  ... quantity quantityUnits  \
# ...

# %%
datos_excel.loc[0:4,['orderIdentifier', 'orderType', 'vendor.organizationIdentifier']]
# Out:
#    orderIdentifier orderType vendor.organizationIdentifier
# 0       1000567495   INBOUND                         F & M
# 1       1000567490   INBOUND                       Luminar
# 2       1000567484   INBOUND                      Flexilux
# 3       1000567483   INBOUND                       Brewers
# 4       1000567481   INBOUND                        McGrey

# %%
datos_excel.iloc[:,0:3]
# Out:
#      orderIdentifier orderType vendor.organizationIdentifier
# 0         1000567495   INBOUND                         F & M
# 1         1000567490   INBOUND                       Luminar
# 2         1000567484   INBOUND                      Flexilux
# 3         1000567483   INBOUND                       Brewers
# 4         1000567481   INBOUND                        McGrey
# ..               ...       ...                           ...
# 163       1000567351   INBOUND                  Total Source
# 164       1000567364   INBOUND                       Mueller
# 165       1000567374   INBOUND                            EM
# 166       1000567376   INBOUND                        Ripley
# 167       1000567378   INBOUND                    Interalloy
#
# [168 rows x 3 columns]

# %% [markdown]
# ___iloc___
#
# Me sirve para acceder a las filas por la posicion en donde se encuentran

# %%
datos_excel.set_index('orderIdentifier', inplace=True)

# %%
datos_excel
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# ...

# %%
datos_excel.iloc[0:10]
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# 1000567478        INBOUND                  Total Source
# 1000567477        INBOUND                         Hardy
# 1000567476        INBOUND                            EM
# 1000567473        INBOUND                        McGrey
# 1000567468        INBOUND                       Mueller
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# 1000567481                         LightTree
# ...

# %% [markdown]
# ### 3.5. Agregar columnas

# %%
## Agregar un valor unico a todas las filas de una columna
datos_excel['valor_unico'] = 'HOLAAAA'
datos_excel
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# ...

# %%
## Agregar una columna calculada a partir de otras columnas
datos_excel['total_value_iva'] = datos_excel['precio_unitario_iva'] * datos_excel['quantity']
datos_excel
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# ...

# %%
def extraer_ubicacion(locationIdentifier):
    resultado = locationIdentifier.split('-')
    i = 0
    while i < len(resultado):
        valor = resultado[i]
        ## Strip me sirve para quitar los espacios en blanco al principio y al final de cada valor
        valor = valor.strip()
        resultado[i] = valor
        i += 1
        
    return resultado[1]

# %%
extraer_ubicacion('AHTD - Bentonville')
# Out:
# 'Bentonville'

# %%
## Agregar una columna calculada a partir de otras columnas utilizando una funcion personalizada con apply
datos_excel['ubicacion'] = datos_excel['shipToLocation.locationIdentifier'].apply(extraer_ubicacion)
datos_excel
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# ...

# %% [markdown]
# ### 3.6. Eliminar columnas

# %%
datos_excel.drop(columns=["valor_unico"], inplace=True)
datos_excel.head()
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# 1000567481                         LightTree
#
#                 shipFromInstructionLocation.locationIdentifier  \
# orderIdentifier
# 1000567495                                    F & M - Columbus
# 1000567490                        Luminar - Palm Beach Gardens
# 1000567484                                Flexilux - Worcester
# ...

# %%
## Alterar orden de las columnas

datos_excel.head()
datos_excel_2 = datos_excel[['orderType',	'vendor.organizationIdentifier',	'shipFromInstructionLocation.locationIdentifier',	'buyer.organizationIdentifier', 'shipToLocation.locationIdentifier',	'orderStatus',	'createdDate','requestedShipDate','requestedDeliveryDate' , 'quantityUnits','totalValue','orderValueCurrency','lineCount','totalShippedQuantity','exclude','sourceLink','precio_unitario','precio_unitario_iva','total_value_iva']]
datos_excel_2.head()
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
#
#                 shipFromInstructionLocation.locationIdentifier  \
# orderIdentifier
# 1000567495                                    F & M - Columbus
# 1000567490                        Luminar - Palm Beach Gardens
# 1000567484                                Flexilux - Worcester
# 1000567483                                   Brewers - Phoenix
# 1000567481                                McGrey - Mt Sterling
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# ...

# %% [markdown]
# ### 3.7. Quitar duplicados

# %%
## Comprobar que existen duplicados en una columna
datos_excel.duplicated(subset=['orderType'])
# Out:
# orderIdentifier
# 1000567495    False
# 1000567490     True
# 1000567484     True
# 1000567483     True
# 1000567481     True
#               ...
# 1000567351     True
# 1000567364     True
# 1000567374     True
# 1000567376     True
# 1000567378     True
# Length: 168, dtype: bool

# %%
datos_excel[['orderType','vendor.organizationIdentifier']]
# Out:
#                 orderType vendor.organizationIdentifier
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
# [168 rows x 2 columns]

# %%
## Comprobar que existen duplicados en multiples columnas
datos_excel.duplicated(subset=['orderType','vendor.organizationIdentifier'])
# Out:
# orderIdentifier
# 1000567495    False
# 1000567490    False
# 1000567484    False
# 1000567483    False
# 1000567481    False
#               ...
# 1000567351     True
# 1000567364     True
# 1000567374     True
# 1000567376     True
# 1000567378     True
# Length: 168, dtype: bool

# %%
## Suma los duplicados --> 0 siginifica que no hay filas duplicadas en el DataFrame
datos_excel.duplicated().sum()
# Out:
# np.int64(0)

# %%
## Borrar duplicados del DataFrame
datos_excel.drop_duplicates(inplace=True)

# %%
datos_excel_inbound = datos_excel[datos_excel['orderType'] == 'INBOUND']

# %%
datos_excel_inbound
# Out:
#                 orderType vendor.organizationIdentifier  \
# orderIdentifier
# 1000567495        INBOUND                         F & M
# 1000567490        INBOUND                       Luminar
# 1000567484        INBOUND                      Flexilux
# 1000567483        INBOUND                       Brewers
# 1000567481        INBOUND                        McGrey
# ...                   ...                           ...
# 1000567351        INBOUND                  Total Source
# 1000567364        INBOUND                       Mueller
# 1000567374        INBOUND                            EM
# 1000567376        INBOUND                        Ripley
# 1000567378        INBOUND                    Interalloy
#
#                 buyer.organizationIdentifier  \
# orderIdentifier
# 1000567495                         LightTree
# 1000567490                         LightTree
# 1000567484                         LightTree
# 1000567483                         LightTree
# ...

# %% [markdown]
# ### 3.8. Agrupar datos

# %%
## Agrupacion sencilla por una columna y calculo de la media de otra columna
datos_excel.groupby('orderType')['totalValue'].mean()
# Out:
# orderType
# INBOUND    106157.785714
# Name: totalValue, dtype: float64

# %%
## Agrupacion por varias columnas y calculo de la media de varios datos de valores distintos
datos_excel.groupby(['orderType','buyer.organizationIdentifier'])[['quantity','totalValue']].mean()
# Out:
#                                           quantity     totalValue
# orderType buyer.organizationIdentifier
# INBOUND   LightTree                     283.410714  106157.785714

# %% [markdown]
# ### 3.9. Merge

# %% [markdown]
# ![Diagrama de JOINs en SQL](https://www.hostingplus.com.co/wp-content/uploads/2021/06/JOIN.jpg)

# %%
catalogo = pd.read_excel('archivo_excel.xlsx', sheet_name='Catalogo')

# %%
catalogo
# Out:
#   buyer.organizationIdentifier                           publicName  \
# 0                         AHTD   Apex Highway Technologies Division
# 1                      CALTRAN                 CalTranscend Systems
# 2                         COLA              Core Logistics Alliance
# 3                          FAA                Flight Axis Authority
# 4                         KYTC                 Kinetic Transit Core
# 5                    LightTree                LightTree Innovations
# 6                         MAHD   Meridian Advanced Highway Division
# 7                        NYDOT  New York Digital Operations Transit
# 8                          CAT                   Gatos asociados SA
#
#   creationDate
# 0   2026-04-06
# 1   2025-01-10
# 2   2024-11-18
# 3   2025-02-22
# 4   2023-11-29
# 5   2023-10-07
# 6   2024-01-11
# 7   2022-10-17
# 8   2022-07-14

# %%
merge_ordenes_catalogo = datos_excel.merge(catalogo, left_on ='buyer.organizationIdentifier', right_on='buyer.organizationIdentifier', how='inner')

# %%
merge_ordenes_catalogo[(merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'CAT')| (merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'QPWD')]
# Out:
# Empty DataFrame
# Columns: [orderType, vendor.organizationIdentifier, buyer.organizationIdentifier, shipFromInstructionLocation.locationIdentifier, shipToLocation.locationIdentifier, orderStatus, createdDate, requestedShipDate, requestedDeliveryDate, plannedShipDate, plannedDeliveryDate, quantity, quantityUnits, totalValue, orderValueCurrency, lineCount, totalShippedQuantity, exclude, sourceLink, precio_unitario, precio_unitario_iva, total_value_iva, ubicacion, publicName, creationDate]
# Index: []
#
# [0 rows x 25 columns]

# %%
merge_ordenes_catalogo = datos_excel.merge(catalogo, left_on ='buyer.organizationIdentifier', right_on='buyer.organizationIdentifier', how='left')

# %%
merge_ordenes_catalogo[(merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'CAT')| (merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'QPWD')]
# Out:
# Empty DataFrame
# Columns: [orderType, vendor.organizationIdentifier, buyer.organizationIdentifier, shipFromInstructionLocation.locationIdentifier, shipToLocation.locationIdentifier, orderStatus, createdDate, requestedShipDate, requestedDeliveryDate, plannedShipDate, plannedDeliveryDate, quantity, quantityUnits, totalValue, orderValueCurrency, lineCount, totalShippedQuantity, exclude, sourceLink, precio_unitario, precio_unitario_iva, total_value_iva, ubicacion, publicName, creationDate]
# Index: []
#
# [0 rows x 25 columns]

# %%
merge_ordenes_catalogo = datos_excel.merge(catalogo, left_on ='buyer.organizationIdentifier', right_on='buyer.organizationIdentifier', how='right')
merge_ordenes_catalogo[['vendor.organizationIdentifier', 'buyer.organizationIdentifier', 'publicName']]
# Out:
#     vendor.organizationIdentifier buyer.organizationIdentifier  \
# 0                             NaN                         AHTD
# 1                             NaN                      CALTRAN
# 2                             NaN                         COLA
# 3                             NaN                          FAA
# 4                             NaN                         KYTC
# ..                            ...                          ...
# 171                        Ripley                    LightTree
# 172                    Interalloy                    LightTree
# 173                           NaN                         MAHD
# 174                           NaN                        NYDOT
# 175                           NaN                          CAT
#
#                               publicName
# 0     Apex Highway Technologies Division
# 1                   CalTranscend Systems
# 2                Core Logistics Alliance
# 3                  Flight Axis Authority
# ...

# %%
merge_ordenes_catalogo[(merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'CAT')| (merge_ordenes_catalogo['buyer.organizationIdentifier'] == 'QPWD')]
# Out:
#     orderType vendor.organizationIdentifier buyer.organizationIdentifier  \
# 175       NaN                           NaN                          CAT
#
#     shipFromInstructionLocation.locationIdentifier  \
# 175                                            NaN
#
#     shipToLocation.locationIdentifier  orderStatus createdDate  \
# 175                               NaN          NaN         NaN
#
#     requestedShipDate requestedDeliveryDate plannedShipDate  ... lineCount  \
# 175               NaN                   NaN             NaN  ...       NaN
#
#      totalShippedQuantity exclude  sourceLink precio_unitario  \
# 175                   NaN     NaN         NaN             NaN
#
#      precio_unitario_iva  total_value_iva  ubicacion          publicName  \
# 175                  NaN              NaN        NaN  Gatos asociados SA
#
#      creationDate
# 175    2022-07-14
#
# [1 rows x 25 columns]

# %% [markdown]
# ### 4. Exportar

# %%
merge_ordenes_catalogo.to_csv('merge_ordenes_catalogo.csv')

# %%
merge_ordenes_catalogo.to_csv('merge_ordenes_catalogo.csv', index=False)

# %%
merge_ordenes_catalogo.to_excel('merge_ordenes_catalogo.xlsx', index=False)

# %%
merge_ordenes_catalogo.to_html('merge_ordenes_catalogo.html', index=False)

# %% [markdown]
# ### Otras funcionalidades

# %% [markdown]
# | **Tema**                        | **Descripción**                                                                 | **Funciones/Métodos Clave**                     | **Ejemplo y Resultado**                                                                 |
# |----------------------------------|---------------------------------------------------------------------------------|-------------------------------------------------|-----------------------------------------------------------------------------------------|
# | **Manejo de Datos Faltantes**    | Identificar, eliminar o rellenar datos faltantes.                               | `isna()`, `dropna()`, `fillna()`, `interpolate()`| ```df["columna"].fillna(df["columna"].mean(), inplace=True)```<br>**Resultado:** Rellena los valores faltantes con la media. |
# | **Aplicar Funciones**            | Aplicar funciones personalizadas a columnas o filas.                            | `apply()`, `map()`, `applymap()`                | ```df["columna"] = df["columna"].apply(lambda x: x * 2)```<br>**Resultado:** Multiplica cada valor por 2. |
# | **Ordenar Datos**                | Ordenar DataFrames por columnas o índices.                                      | `sort_values()`, `sort_index()`                 | ```df.sort_values("Value", ascending=False)```<br>**Resultado:** Ordena por "Value" de forma descendente. |
# | **Pivot Tables**                 | Crear tablas dinámicas para resumir datos.                                      | `pivot_table()`                                | ```df.pivot_table(values="Value", index="Country Name", columns="Year", aggfunc="sum")```<br>**Resultado:** Tabla dinámica con la suma de "Value" por país y año. |
# | **Melt y Pivot**                 | Transformar DataFrames entre formatos largo y ancho.                            | `melt()`, `pivot()`                            | ```df.melt(id_vars=["Country Name", "Year"], value_vars=["Value", "Value_2"])```<br>**Resultado:** Convierte el DataFrame a formato largo. |
# | **Concatenación de DataFrames**  | Combinar DataFrames vertical u horizontalmente.                                 | `concat()`                                     | ```pd.concat([df1, df2], axis=0)```<br>**Resultado:** Combina dos DataFrames verticalmente. |
# | **Manejo de Datos de Texto**     | Manipular columnas de texto (extraer, dividir, reemplazar).                     | `str.upper()`, `str.split()`, `str.replace()`  | ```df["columna"] = df["columna"].str.upper()```<br>**Resultado:** Convierte el texto a mayúsculas. |
# | **Manejo de Fechas y Tiempos**   | Trabajar con columnas de fechas y realizar operaciones temporales.              | `pd.to_datetime()`, `dt.year`, `dt.month`      | ```df["fecha"] = pd.to_datetime(df["fecha"])```<br>**Resultado:** Convierte la columna a tipo `datetime`. |
# | **Manejo de Datos Categóricos**  | Convertir columnas a tipo categórico y crear variables dummy.                   | `astype("category")`, `pd.get_dummies()`       | ```df["columna"] = df["columna"].astype("category")```<br>**Resultado:** Convierte la columna a tipo categórico. |
# | **Manejo de Grandes Volúmenes**  | Leer y procesar archivos grandes en bloques.                                    | `chunksize` en `read_csv()`                    | ```for chunk in pd.read_csv("archivo.csv", chunksize=1000): procesar(chunk)```<br>**Resultado:** Lee el archivo en bloques de 1000 filas. |
# | **Exportación de Datos**         | Guardar DataFrames en diferentes formatos (CSV, Excel, JSON, etc.).             | `to_csv()`, `to_excel()`, `to_json()`          | ```df.to_csv("datos.csv", index=False)```<br>**Resultado:** Guarda el DataFrame en un archivo CSV. |
# | **Visualización de Datos**       | Crear gráficos directamente desde pandas.                                       | `plot()`, `hist()`, `boxplot()`                | ```df.plot(x="Year", y="Value", kind="line")```<br>**Resultado:** Genera un gráfico de líneas. |
# | **Optimización de Código**       | Evitar bucles y usar operaciones vectorizadas.                                  | `eval()`, `query()`                            | ```df.query("Value > 1000000")```<br>**Resultado:** Filtra filas donde "Value" es mayor a 1,000,000. |
# | **Trabajo con Multi-Index**      | Crear y manipular DataFrames con múltiples niveles de índice.                   | `set_index()`, `stack()`, `unstack()`          | ```df.set_index(["Country Name", "Year"])```<br>**Resultado:** Crea un DataFrame con Multi-Index. |
# | **Casos Prácticos y Proyectos**  | Ejercicios y proyectos para aplicar lo aprendido en datasets reales.            | -                                              | **Ejemplo:** Análisis de ventas mensuales.<br>**Resultado:** Informe con insights clave. |
